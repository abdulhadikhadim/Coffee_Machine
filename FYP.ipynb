# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulhadikhadim/Coffee_Machine/blob/master/FYP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K

smooth = 1e-15
def dice_coef(y_true, y_pred):
    y_true = tf.keras.layers.Flatten()(y_true)
    y_pred = tf.keras.layers.Flatten()(y_pred)
    intersection = tf.reduce_sum(y_true * y_pred)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)

def dice_loss(y_true, y_pred):
    return 1.0 - dice_coef(y_true, y_pred)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import model_to_dot
from IPython.display import SVG

def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, 2, strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    # print(s1.shape, s2.shape, s3.shape, s4.shape)
    # print(p1.shape, p2.shape, p3.shape, p4.shape)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="UNET")
    return model

if __name__ == "__main__":
    input_shape = (640, 640, 3)
    model = build_unet(input_shape)
    model.summary()
# Out:
# Model: "UNET"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 640, 640, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 640, 640, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 640, 640, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 640, 640, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 640, 640, 64)         36928     ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 640, 640, 64)         256       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 640, 640, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 320, 320, 64)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 320, 320, 128)        73856     ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 320, 320, 128)        512       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 320, 320, 128)        0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 320, 320, 128)        147584    ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 320, 320, 128)        512       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 320, 320, 128)        0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 160, 160, 128)        0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 160, 160, 256)        295168    ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 160, 160, 256)        1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 160, 160, 256)        0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 160, 160, 256)        590080    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 160, 160, 256)        1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 160, 160, 256)        0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 80, 80, 256)          0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 80, 80, 512)          1180160   ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 80, 80, 512)          2048      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 80, 80, 512)          0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 80, 80, 512)          2359808   ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 80, 80, 512)          2048      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 80, 80, 512)          0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 40, 40, 512)          0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 40, 40, 1024)         4719616   ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 40, 40, 1024)         4096      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 40, 40, 1024)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 40, 40, 1024)         9438208   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 40, 40, 1024)         4096      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 40, 40, 1024)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_transpose (Conv2DTr  (None, 80, 80, 512)          2097664   ['activation_9[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 80, 80, 1024)         0         ['conv2d_transpose[0][0]',
#                                                                      'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 80, 80, 512)          4719104   ['concatenate[0][0]']
#
#  batch_normalization_10 (Ba  (None, 80, 80, 512)          2048      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 80, 80, 512)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 80, 80, 512)          2359808   ['activation_10[0][0]']
#
#  batch_normalization_11 (Ba  (None, 80, 80, 512)          2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 80, 80, 512)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 160, 160, 256)        524544    ['activation_11[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 160, 160, 512)        0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 160, 160, 256)        1179904   ['concatenate_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 160, 160, 256)        1024      ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 160, 160, 256)        0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 160, 160, 256)        590080    ['activation_12[0][0]']
#
#  batch_normalization_13 (Ba  (None, 160, 160, 256)        1024      ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 160, 160, 256)        0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 320, 320, 128)        131200    ['activation_13[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 320, 320, 256)        0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 320, 320, 128)        295040    ['concatenate_2[0][0]']
#
#  batch_normalization_14 (Ba  (None, 320, 320, 128)        512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 320, 320, 128)        0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 320, 320, 128)        147584    ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 320, 320, 128)        512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 320, 320, 128)        0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 640, 640, 64)         32832     ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_3 (Concatenate  (None, 640, 640, 128)        0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 640, 640, 64)         73792     ['concatenate_3[0][0]']
#
#  batch_normalization_16 (Ba  (None, 640, 640, 64)         256       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 640, 640, 64)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 640, 640, 64)         36928     ['activation_16[0][0]']
#
#  batch_normalization_17 (Ba  (None, 640, 640, 64)         256       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 640, 640, 64)         0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 640, 640, 1)          65        ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31055297 (118.47 MB)
# Trainable params: 31043521 (118.42 MB)
# Non-trainable params: 11776 (46.00 KB)
# __________________________________________________________________________________________________

# %%
# Save the model architecture as an image
plot_model(model, to_file='model.png')

# Display the model architecture as SVG
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
from sklearn.utils import shuffle
import numpy as np
import cv2
from glob import glob
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from unet import build_unet
from metrics import dice_loss, dice_coef

""" Global parameters """
H = 640
W = 640

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def load_dataset(path, split=0.2, test_size=0.2):
    images = sorted(glob(os.path.join(path, "images", "*.png")))
    masks = sorted(glob(os.path.join(path, "masks", "*.png")))

    # Use test_size as specified, or set a default value if not provided
    if test_size <= 0 or test_size >= 1:
        test_size = 0.2

    split_size = int(len(images) * split)

    train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
    train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)

    # Check if test_size is greater than 0 before splitting test set
    if test_size > 0:
        train_x, test_x = train_test_split(train_x, test_size=test_size, random_state=42)
        train_y, test_y = train_test_split(train_y, test_size=test_size, random_state=42)
    else:
        test_x, test_y = [], []

    return (train_x, train_y), (valid_x, valid_y), (test_x, test_y)



def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x

def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x

def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y

def tf_dataset(X, Y, batch=2):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("files")

    """ Hyperparameters """
    batch_size = 4
    lr = 1e-4
    num_epochs = 500
    model_path = os.path.join("files", "model.h5")
    csv_path = os.path.join("files", "log.csv")

    """ Dataset """
    dataset_path = "drive/My Drive/Data"
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")
    print(f"Test : {len(test_x)} - {len(test_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = build_unet((H, W, 3))
    model.compile(loss=dice_loss, optimizer=Adam(lr), metrics=[dice_coef])

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=False),
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
# Out:
# Train: 321 - 321
# Valid: 107 - 107
# Test : 107 - 107
# Epoch 1/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9989 - dice_coef: 0.0011
# Epoch 1: val_loss improved from inf to 0.99967, saving model to files/model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 81/81 [==============================] - 225s 2s/step - loss: 0.9989 - dice_coef: 0.0011 - val_loss: 0.9997 - val_dice_coef: 3.2659e-04 - lr: 1.0000e-04
# Epoch 2/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9975 - dice_coef: 0.0025
# Epoch 2: val_loss did not improve from 0.99967
# 81/81 [==============================] - 135s 2s/step - loss: 0.9975 - dice_coef: 0.0025 - val_loss: 0.9997 - val_dice_coef: 3.2579e-04 - lr: 1.0000e-04
# Epoch 3/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9967 - dice_coef: 0.0033
# Epoch 3: val_loss improved from 0.99967 to 0.99966, saving model to files/model.h5
# 81/81 [==============================] - 144s 2s/step - loss: 0.9967 - dice_coef: 0.0033 - val_loss: 0.9997 - val_dice_coef: 3.3938e-04 - lr: 1.0000e-04
# Epoch 4/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9961 - dice_coef: 0.0039
# Epoch 4: val_loss improved from 0.99966 to 0.99965, saving model to files/model.h5
# 81/81 [==============================] - 139s 2s/step - loss: 0.9961 - dice_coef: 0.0039 - val_loss: 0.9996 - val_dice_coef: 3.4992e-04 - lr: 1.0000e-04
# Epoch 5/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9956 - dice_coef: 0.0044
# Epoch 5: val_loss improved from 0.99965 to 0.99929, saving model to files/model.h5
# 81/81 [==============================] - 141s 2s/step - loss: 0.9956 - dice_coef: 0.0044 - val_loss: 0.9993 - val_dice_coef: 7.0770e-04 - lr: 1.0000e-04
# Epoch 6/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9951 - dice_coef: 0.0049
# Epoch 6: val_loss improved from 0.99929 to 0.99803, saving model to files/model.h5
# 81/81 [==============================] - 147s 2s/step - loss: 0.9951 - dice_coef: 0.0049 - val_loss: 0.9980 - val_dice_coef: 0.0020 - lr: 1.0000e-04
# Epoch 7/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9947 - dice_coef: 0.0053
# Epoch 7: val_loss improved from 0.99803 to 0.99574, saving model to files/model.h5
# 81/81 [==============================] - 137s 2s/step - loss: 0.9947 - dice_coef: 0.0053 - val_loss: 0.9957 - val_dice_coef: 0.0043 - lr: 1.0000e-04
# Epoch 8/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9943 - dice_coef: 0.0057
# Epoch 8: val_loss improved from 0.99574 to 0.99479, saving model to files/model.h5
# 81/81 [==============================] - 136s 2s/step - loss: 0.9943 - dice_coef: 0.0057 - val_loss: 0.9948 - val_dice_coef: 0.0052 - lr: 1.0000e-04
# Epoch 9/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9941 - dice_coef: 0.0059
# Epoch 9: val_loss did not improve from 0.99479
# 81/81 [==============================] - 135s 2s/step - loss: 0.9941 - dice_coef: 0.0059 - val_loss: 0.9948 - val_dice_coef: 0.0052 - lr: 1.0000e-04
# Epoch 10/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9938 - dice_coef: 0.0062
# Epoch 10: val_loss improved from 0.99479 to 0.99437, saving model to files/model.h5
# 81/81 [==============================] - 137s 2s/step - loss: 0.9938 - dice_coef: 0.0062 - val_loss: 0.9944 - val_dice_coef: 0.0056 - lr: 1.0000e-04
# Epoch 11/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9936 - dice_coef: 0.0064
# Epoch 11: val_loss improved from 0.99437 to 0.99392, saving model to files/model.h5
# 81/81 [==============================] - 137s 2s/step - loss: 0.9936 - dice_coef: 0.0064 - val_loss: 0.9939 - val_dice_coef: 0.0061 - lr: 1.0000e-04
# Epoch 12/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9934 - dice_coef: 0.0066
# Epoch 12: val_loss did not improve from 0.99392
# 81/81 [==============================] - 135s 2s/step - loss: 0.9934 - dice_coef: 0.0066 - val_loss: 0.9939 - val_dice_coef: 0.0061 - lr: 1.0000e-04
# Epoch 13/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9933 - dice_coef: 0.0068
# Epoch 13: val_loss improved from 0.99392 to 0.99365, saving model to files/model.h5
# 81/81 [==============================] - 137s 2s/step - loss: 0.9933 - dice_coef: 0.0068 - val_loss: 0.9936 - val_dice_coef: 0.0064 - lr: 1.0000e-04
# Epoch 14/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9931 - dice_coef: 0.0069
# Epoch 14: val_loss improved from 0.99365 to 0.99357, saving model to files/model.h5
# 81/81 [==============================] - 137s 2s/step - loss: 0.9931 - dice_coef: 0.0069 - val_loss: 0.9936 - val_dice_coef: 0.0064 - lr: 1.0000e-04
# Epoch 15/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9930 - dice_coef: 0.0070
# Epoch 15: val_loss improved from 0.99357 to 0.99342, saving model to files/model.h5
# 81/81 [==============================] - 136s 2s/step - loss: 0.9930 - dice_coef: 0.0070 - val_loss: 0.9934 - val_dice_coef: 0.0066 - lr: 1.0000e-04
# Epoch 16/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9929 - dice_coef: 0.0071
# Epoch 16: val_loss did not improve from 0.99342
# 81/81 [==============================] - 135s 2s/step - loss: 0.9929 - dice_coef: 0.0071 - val_loss: 0.9935 - val_dice_coef: 0.0065 - lr: 1.0000e-04
# Epoch 17/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9928 - dice_coef: 0.0072
# Epoch 17: val_loss did not improve from 0.99342
# 81/81 [==============================] - 135s 2s/step - loss: 0.9928 - dice_coef: 0.0072 - val_loss: 0.9936 - val_dice_coef: 0.0064 - lr: 1.0000e-04
# Epoch 18/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9927 - dice_coef: 0.0073
# Epoch 18: val_loss did not improve from 0.99342
# 81/81 [==============================] - 135s 2s/step - loss: 0.9927 - dice_coef: 0.0073 - val_loss: 0.9938 - val_dice_coef: 0.0062 - lr: 1.0000e-04
# Epoch 19/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9927 - dice_coef: 0.0073
# Epoch 19: val_loss improved from 0.99342 to 0.99320, saving model to files/model.h5
# 81/81 [==============================] - 147s 2s/step - loss: 0.9927 - dice_coef: 0.0073 - val_loss: 0.9932 - val_dice_coef: 0.0068 - lr: 1.0000e-04
# Epoch 20/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9926 - dice_coef: 0.0074
# Epoch 20: val_loss did not improve from 0.99320
# 81/81 [==============================] - 141s 2s/step - loss: 0.9926 - dice_coef: 0.0074 - val_loss: 0.9933 - val_dice_coef: 0.0067 - lr: 1.0000e-04
# Epoch 21/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9926 - dice_coef: 0.0074
# Epoch 21: val_loss did not improve from 0.99320
# 81/81 [==============================] - 135s 2s/step - loss: 0.9926 - dice_coef: 0.0074 - val_loss: 0.9933 - val_dice_coef: 0.0067 - lr: 1.0000e-04
# Epoch 22/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9926 - dice_coef: 0.0074
# Epoch 22: val_loss did not improve from 0.99320
# 81/81 [==============================] - 135s 2s/step - loss: 0.9926 - dice_coef: 0.0074 - val_loss: 0.9934 - val_dice_coef: 0.0066 - lr: 1.0000e-04
# Epoch 23/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9925 - dice_coef: 0.0075
# Epoch 23: val_loss did not improve from 0.99320
# 81/81 [==============================] - 135s 2s/step - loss: 0.9925 - dice_coef: 0.0075 - val_loss: 0.9933 - val_dice_coef: 0.0067 - lr: 1.0000e-04
# Epoch 24/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9925 - dice_coef: 0.0075
# Epoch 24: val_loss improved from 0.99320 to 0.99299, saving model to files/model.h5
# 81/81 [==============================] - 144s 2s/step - loss: 0.9925 - dice_coef: 0.0075 - val_loss: 0.9930 - val_dice_coef: 0.0070 - lr: 1.0000e-04
# Epoch 25/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9926 - dice_coef: 0.0074
# Epoch 25: val_loss did not improve from 0.99299
# 81/81 [==============================] - 135s 2s/step - loss: 0.9926 - dice_coef: 0.0074 - val_loss: 0.9996 - val_dice_coef: 3.8843e-04 - lr: 1.0000e-04
# Epoch 26/500
# 81/81 [==============================] - ETA: 0s - loss: 0.
500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 80: val_loss improved from 0.99288 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 136s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 81/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 81: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 145s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 82/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 82: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 133s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 83/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 83: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 147s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 84/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 84: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 133s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 85/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 85: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 139s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 86/500
# 81/81 [==============================] - ETA: 0s - loss: 0.9924 - dice_coef: 0.0076
# Epoch 86: val_loss improved from 0.99287 to 0.99287, saving model to files/model.h5
# 81/81 [==============================] - 145s 2s/step - loss: 0.9924 - dice_coef: 0.0076 - val_loss: 0.9929 - val_dice_coef: 0.0071 - lr: 1.0000e-07
# Epoch 87/500
# 79/81 [============================>.] - ETA: 3s - loss: 0.9924 - dice_coef: 0.0076

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.utils import CustomObjectScope
from sklearn.metrics import f1_score, jaccard_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from metrics import dice_loss, dice_coef
from train import load_dataset
from unet import build_unet

""" Global parameters """
H = 640
W = 640

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def save_results(image, mask, y_pred, save_image_path):
    mask = np.expand_dims(mask, axis=-1)
    mask = np.concatenate([mask, mask, mask], axis=-1)

    y_pred = np.expand_dims(y_pred, axis=-1)
    y_pred = np.concatenate([y_pred, y_pred, y_pred], axis=-1)
    y_pred = y_pred * 255

    line = np.ones((H, 10, 3)) * 255

    cat_images = np.concatenate([image, line, mask, line, y_pred], axis=1)
    cv2.imwrite(save_image_path, cat_images)


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)

    """ Directory for storing files """
    create_dir("results")

    """ Load the model """
    with CustomObjectScope({"dice_coef": dice_coef, "dice_loss": dice_loss}):
        model = tf.keras.models.load_model(os.path.join("files", "model.h5"))

    """ Dataset """
    dataset_path = "drive/My Drive/Data"
    # Use the updated load_dataset function
    (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)

    """ Prediction and Evaluation """
    SCORE = []
    for x, y in tqdm(zip(test_x, test_y), total=len(test_y)):
        """ Extracting the name """
        name = x.split("/")[-1]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)  # [H, w, 3]
        image = cv2.resize(image, (W, H))  # [H, w, 3]
        x = image / 255.0  # [H, w, 3]
        x = np.expand_dims(x, axis=0)  # [1, H, w, 3]

        """ Reading the mask """
        mask = cv2.imread(y, cv2.IMREAD_GRAYSCALE)
        mask = cv2.resize(mask, (W, H))

        """ Prediction """
        y_pred = model.predict(x, verbose=0)[0]
        y_pred = np.squeeze(y_pred, axis=-1)
        y_pred = y_pred >= 0.5
        y_pred = y_pred.astype(np.int32)

        """ Saving the prediction """
        save_image_path = os.path.join("results", name)
        save_results(image, mask, y_pred, save_image_path)

        """ Flatten the array """
        mask = mask / 255.0
        mask = (mask > 0.5).astype(np.int32).flatten()
        y_pred = y_pred.flatten()

        """ Calculating the metrics values """
        f1_value = f1_score(mask, y_pred, labels=[0, 1], average="binary")
        jac_value = jaccard_score(mask, y_pred, labels=[0, 1], average="binary")
        recall_value = recall_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        precision_value = precision_score(mask, y_pred, labels=[0, 1], average="binary", zero_division=0)
        SCORE.append([name, f1_value, jac_value, recall_value, precision_value])

    """ Metrics values """
    score = [s[1:] for s in SCORE]
    score = np.mean(score, axis=0)
    print(f"F1: {score[0]:0.5f}")
    print(f"Jaccard: {score[1]:0.5f}")
    print(f"Recall: {score[2]:0.5f}")
    print(f"Precision: {score[3]:0.5f}")

    df = pd.DataFrame(SCORE, columns=["Image", "F1", "Jaccard", "Recall", "Precision"])
    df.to_csv("files/score.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-4c44d86ac396> in <cell line: 40>()
#      53     dataset_path = "drive/My Drive/Data"
#      54     # Use the updated load_dataset function
# ---> 55     (train_x, train_y), (valid_x, valid_y), (test_x, test_y) = load_dataset(dataset_path)
#      56
#      57     """ Prediction and Evaluation """
#
# /content/train.py in load_dataset(path, split)
#      28     split_size = int(len(images) * split)
#      29
# ---> 30     train_x, valid_x = train_test_split(images, test_size=split_size, random_state=42)
#      31     train_y, valid_y = train_test_split(masks, test_size=split_size, random_state=42)
#      32
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2560
#    2561     n_samples = _num_samples(arrays[0])
# -> 2562     n_train, n_test = _validate_shuffle_split(
#    2563         n_samples, test_size, train_size, default_test_size=0.25
#    2564     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2179         and (test_size <= 0 or test_size >= 1)
#    2180     ):
# -> 2181         raise ValueError(
#    2182             "test_size={0} should be either positive and smaller"
#    2183             " than the number of samples {1} or a float in the "
#
# ValueError: test_size=0 should be either positive and smaller than the number of samples 0 or a float in the (0, 1) range
